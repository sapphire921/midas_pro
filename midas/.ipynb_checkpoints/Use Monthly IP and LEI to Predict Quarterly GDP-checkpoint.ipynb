# %% [markdown]
# # Use Monthly IP and LEI to Predict Quarterly GDP

# %% [markdown]
# Author: Zhuping Xu

# %%
# %matplotlib inline
import datetime
import numpy as np
import pandas as pd

from mix import mix_freq, mix_freq2
from adl import estimate, forecast, midas_adl, rmse, estimate2,forecast2, midas_adl2

# %%
# Read data
gdp = pd.read_csv('GDP.csv', parse_dates=['DATE'], index_col='DATE')
ip = pd.read_csv('IP.csv', parse_dates=['DATE'], index_col='DATE')
lei = pd.read_csv('LEI.csv', parse_dates=['DATE'], index_col='DATE')
gdp.tail()
# Out:
#             GDP_CYOY
# DATE
# 2017-03-31       2.0
# 2017-06-30       2.2
# 2017-09-30       2.3
# 2017-12-31       2.6
# 2018-03-31       2.8

# %%
ip.tail()
# Out:
#             IP_YOY
# DATE
# 2017-12-31    2.85
# 2018-01-31    2.71
# 2018-02-28    3.51
# 2018-03-31    3.71
# 2018-04-30    3.50

# %%
lei.tail()
# Out:
#             LEI_YOY
# DATE
# 2017-12-31      5.7
# 2018-01-31      5.9
# 2018-02-28      6.4
# 2018-03-31      6.2
# 2018-04-30      6.4

# %%
# Plot the sample data
df = pd.concat([gdp, ip, lei], axis=1)
df.columns = ['gdp_yoy','ip_yoy','lei_yoy']
df[['gdp_yoy','ip_yoy','lei_yoy']].loc['2011-1-31':].plot(figsize=(15,4), style=['o','-','--'])

# %% [markdown]
# ## Mixing Frequencies
#
# The first step is to do the actual frequency mixing.  In this case we're mixing monthly data (industrial producation % yoy growth, leading indicator %yoy) with quarterly data (gdp % yoy growth).

# %%
y, yl, x1, x2, yf, ylf, x1f, x2f =mix_freq2(gdp.GDP_CYOY, ip.IP_YOY,lei.LEI_YOY, "3m","3m", 1, 2,
                                 start_date=datetime.datetime(2011,3,31),
                                 end_date=datetime.datetime(2013,3,31))

# %% [markdown]
# ## Fitting the Model
#
# Because of the form of the MIDAS model, fitting the model requires using non-linear least squares.  For now, if you call the __estimate2__ function directly, you'll get back a results of type scipy.optimize.optimize.OptimizeResult. We use data from 2011-3-31 to 2013-3-31 to fit the model and use the rest of data to forecast.

# %%
res = estimate2(y, yl, x1, x2, poly1='expalmon', poly2='expalmon')
res.x
#opt params [beta0, beta1, beta2, theta11, theta12, theta21, theta22, lambda]
# Out:
# array([  0.62437404,   0.81585015,  -0.19729317,  41.18721465,
#        -14.43965163,   1.00688134,   9.92375974,  -0.20844232])

# %% [markdown]
# You can also call __forecast2__ directly.  This will use the optimization results returned from __eatimate2__ to produce a forecast for every date in the index of the forecast inputs (here x1f, x2f and ylf):

# %%
fc = forecast2(x1f, x2f, ylf, res, poly1='expalmon',poly2='expalmon')
forecast_df = fc.join(yf)
forecast_df['gap'] = forecast_df.yfh - forecast_df.GDP_CYOY
forecast_df
# Out:
#                  yfh  GDP_CYOY       gap
# DATE
# 2013-06-30  1.528353       1.0  0.528353
# 2013-09-30  0.990148       1.7 -0.709852
# 2013-12-31  1.546407       2.7 -1.153593
# 2014-03-31  0.607871       1.7 -1.092129
# 2014-06-30  1.825257       2.7 -0.874743
# 2014-09-30  2.250579       3.2 -0.949421
# 2014-12-31  1.362318       2.7 -1.337682
# 2015-03-31  1.529287       3.8 -2.270713
# 2015-06-30 -1.296682       3.3 -4.596682
# 2015-09-30 -2.122371       2.4 -4.522371
# 2015-12-31 -2.486361       2.0 -4.486361
# 2016-03-31 -2.710368       1.4 -4.110368
# 2016-06-30 -2.276044       1.2 -3.476044
# 2016-09-30 -1.382462       1.5 -2.882462
# 2016-12-31 -0.973948       1.8 -2.773948
# 2017-03-31 -0.234338       2.0 -2.234338
# 2017-06-30  1.143309       2.2 -1.056691
# 2017-09-30  0.648216       2.3 -1.651784
# 2017-12-31  1.334874       2.6 -1.265126
# 2018-03-31  1.200649       2.8 -1.599351

# %% [markdown]
# ## The midas_adl and midas_adl2 function
#
# The __midas\_adl__ and __midas\_adl2__ function wraps up frequency-mixing, fitting, and forecasting into one process.  The default mode of forecasting is _rolling_.

# %% [markdown]
# ### Use one monthly indicator

# %%
# use IP_YOY
rmse_fc1, fc1 = midas_adl(gdp.GDP_CYOY, ip.IP_YOY, 
                         start_date=datetime.datetime(2011,3,31),
                         end_date=datetime.datetime(2013,3,31),
                         xlag="3m",
                         ylag=1,
                         horizon=1,
                         poly='expalmon',
                         method='rolling')
rmse_fc1
# Out:
# 0.94690137628561111

# %%
# use LEI_YOY
rmse_fc2, fc2 = midas_adl(gdp.GDP_CYOY, lei.LEI_YOY, 
                         start_date=datetime.datetime(2011,3,31),
                         end_date=datetime.datetime(2013,3,31),
                         xlag="3m",
                         ylag=1,
                         horizon=1,
                         poly='expalmon',
                         method='rolling')
rmse_fc2
# Out:
# 0.66873706617083828

# %% [markdown]
# ### Use two monthly indicator

# %%
# use IP_YOY and LEI_YOY
rmse_fc, fc = midas_adl2(gdp.GDP_CYOY, ip.IP_YOY,lei.LEI_YOY, 
                         start_date=datetime.datetime(2011,3,31),
                         end_date=datetime.datetime(2013,3,31),
                         x1lag="3m",
                         x2lag="3m",
                         ylag=1,
                         horizon=1,
                         poly1='expalmon',
                         poly2='expalmon',
                         method='rolling')
rmse_fc
# Out:
# 0.77103448623420145

# %% [markdown]
# # Forecast quarterly GDP

# %%
# Set start date and end date
start_date=datetime.datetime(2011,3,31)
end_date=datetime.datetime(2013,3,31)

# %%
df_result=pd.DataFrame(index=ip.index, columns=['final_gdp_date'])
temp=df_result.iloc[2::3].reset_index()
for i in range(0,len(temp)):
    df_result['final_gdp_date'][i*3+2]=temp['DATE'][i].date()
df_result[['final_gdp_date','GDP_CYOY']]=df_result.join(gdp)[['final_gdp_date','GDP_CYOY']].fillna(method='bfill')

# %%
# To compute benchmark forecast
n_month=df_result.index.get_loc(end_date)-df_result.index.get_loc(start_date)
df_result['benchmark']=df_result['GDP_CYOY'].rolling(window=n_month).mean()
df_result
# Out:
#            final_gdp_date  GDP_CYOY  benchmark
# DATE
# 2011-01-31     2011-03-31       1.9        NaN
# 2011-02-28     2011-03-31       1.9        NaN
# %%
# Forecast_all, n is the max horizon, we will set n=3
def forecast_all(y_in, x1_in, x2_in, start_date, end_date, x1lag, x2lag, ylag,n, 
                 forecast_horizon, poly1, poly2, method='rolling'):
    forecast_result=[]
    rmse_result=[]
    for i in range(n):
        rmse,fc=midas_adl2(y_in, x1_in, x2_in, start_date=start_date, end_date=end_date,
                           x1lag=x1lag, x2lag=x2lag, ylag=ylag, horizon=i,
                           poly1=poly1, poly2=poly2, method=method)
        forecast_result.append(fc)
        rmse_result.append(rmse)
    return forecast_result, rmse_result

# %%
# Define a function to assist storing forecast gdp to df_result
def store_gdp(df0,df1,df2,df):
    df0=df0.reset_index()
    df0['DATE']=df0['index']
    df0=df0.drop(['index','targets'],axis=1)
    
    df1=df1.reset_index()
    df1['DATE']=df1['index']
    df1=df1.drop(['index','targets'],axis=1)
    
    df2=df2.reset_index()
    df2['DATE']=df2['index']
    df2=df2.drop(['index','targets'],axis=1)
    
    df_result=df.copy()
    df_result=df_result.reset_index()
    df_result=df_result.merge(df2,how='left',on='DATE')
    df_result=df_result.merge(df1,how='left',on='DATE')
    df_result=df_result.merge(df0,how='left',on='DATE')
    
    df_result['preds_x']=df_result['preds_x'].shift(-2)
    df_result['preds_y']=df_result['preds_y'].shift(-1)
    df_result=df_result.fillna(0)
    df_result['forecast_gdp']=df_result['preds_x']+df_result['preds_y']+df_result['preds']
    df_result=df_result.drop(['preds_x','preds_y','preds'],axis=1).set_index('DATE')
    
    return df_result

# %% [markdown]
# ## (1) Use MIDAS with two indicators on a rolling basis

# %% [markdown]
# Both two indicators use lags of 3 months.

# %%
# n=3, ylag=0, method='rolling'
df_fc1, rmse1=forecast_all(gdp.GDP_CYOY, ip.IP_YOY,lei.LEI_YOY, start_date, end_date, 
                           x1lag='3m',x2lag='3m', ylag=0, n=3, forecast_horizon=1, 
                           poly1='expalmon', poly2='expalmon', method='rolling')

# %%
rmse1
# Out:
# [0.69488785638649131, 0.71087750370453473, 0.71759053577034526]

# %%
# Store forecast results in df_result
df_result1=store_gdp(df_fc1[0],df_fc1[1],df_fc1[2],df_result)

# %%
# Forecast results
df_result1.iloc[df_result1.index.get_loc(end_date)+1:]
# Out:
#            final_gdp_date  GDP_CYOY  benchmark  forecast_gdp
# DATE
# 2013-04-30     2013-06-30       1.0   1.833333      1.516998
# 2013-05-31     2013-06-30       1.0   1.804167      1.525924
# 2013-06-30     2013-06-30       1.0   1.775000      1.332685
# 2013-07-31     2013-09-30       1.7   1.795833      0.736541
# 2013-08-31     2013-09-30       1.7   1.816667      0.833724
# 2013-09-30     2013-09-30       1.7   1.837500      0.946365
# 2013-10-31     2013-12-31       2.7   1.879167      1.551186
# 2013-11-30     2013-12-31       2.7   1.920833      1.456141
# 2013-12-31     2013-12-31       2.7   1.962500      1.330880
# 2014-01-31     2014-03-31       1.7   1.916667      2.356490
# 2014-02-28     2014-03-31       1.7   1.870833      1.866612
# 2014-03-31     2014-03-31       1.7   1.825000      2.355498
# 2014-04-30     2014-06-30       2.7   1.833333      3.005957
# 2014-05-31     2014-06-30       2.7   1.841667      3.042983
# 2014-06-30     2014-06-30       2.7   1.850000      3.065387
# 2014-07-31     2014-09-30       3.2   1.883333      3.501334
# 2017-04-30     2017-06-30       2.2   1.904167      2.011585
# 2017-05-31     2017-06-30       2.2   1.858333      2.147158
# 2017-06-30     2017-06-30       2.2   1.812500      2.135295
# 2017-07-31     2017-09-30       2.3   1.808333      2.315814
# 2017-08-31     2017-09-30       2.3   1.804167      2.260509
# 2017-09-30     2017-09-30       2.3   1.800000      2.268000
# 2017-10-31     2017-12-31       2.6   1.825000      2.269384
# 2017-11-30     2017-12-31       2.6   1.850000      2.496008
# 2017-12-31     2017-12-31       2.6   1.875000      2.621195
# 2018-01-31     2018-03-31       2.8   1.933333      0.000000
# 2018-02-28     2018-03-31       2.8   1.991667      0.000000
# 2018-03-31     2018-03-31       2.8   2.050000      0.000000
# 2018-04-30              0       0.0   0.000000      0.000000
#
# [61 rows x 4 columns]

# %%
# Measure forecast accuracy
temp2=df_result2[df_result2['forecast_gdp']!=0]
relative_mse2=((temp2['GDP_CYOY']-temp2['forecast_gdp'])**2).mean()/((temp2['GDP_CYOY']-temp2['benchmark'])**2).mean()
relative_mse2
# Out:
# 1.2250207752288573

# %% [markdown]
# ## (3) Use autoregressive MIDAS with two indicators on a rolling basis

# %%
# n=3, ylag=1, method='rolling'
df_fc3, rmse3=forecast_all(gdp.GDP_CYOY, ip.IP_YOY, lei.LEI_YOY, start_date, end_date, 
                           x1lag='3m',x2lag='3m', ylag=1, n=3, forecast_horizon=1, 
                           poly1='expalmon', poly2='expalmon', method='rolling')

# %%
rmse3
# Out:
# [0.76897473288853602, 0.77103465107634739, 1.0473843175200781]

# %%
# Store forecast results in df_result
df_result3=store_gdp(df_fc3[0],df_fc3[1],df_fc3[2],df_result)

# %%
df_result3.iloc[df_result3.index.get_loc(end_date)+1:]
# Out:
#            final_gdp_date  GDP_CYOY  benchmark  forecast_gdp
# DATE
# 2013-04-30     2013-06-30       1.0   1.833333      1.528353
# 2013-05-31     2013-06-30       1.0   1.804167      1.589848
# 2013-06-30     2013-06-30       1.0   1.775000      1.397939
# 2013-07-31     2013-09-30       1.7   1.795833      0.811102
# 2013-08-31     2013-09-30       1.7   1.816667      0.850714
# 2013-09-30     2013-09-30       1.7   1.837500      0.945653
# 2013-10-31     2013-12-31       2.7   1.879167      1.461670
# 2013-11-30     2013-12-31       2.7   1.920833      1.462482
# 2013-12-31     2013-12-31       2.7   1.962500      1.324602
# 2014-01-31     2014-03-31       1.7   1.916667      2.138428
# 2014-02-28     2014-03-31       1.7   1.870833      2.334858
# 2014-03-31     2014-03-31       1.7   1.825000      3.056437
# 2014-04-30     2014-06-30       2.7   1.833333      3.280031
# 2014-05-31     2014-06-30       2.7   1.841667      3.113778
# 2014-06-30     2014-06-30       2.7   1.850000      3.160418
# 2014-07-31     2014-09-30       3.2   1.883333      3.538885
# 2014-08-31     2014-09-30       3.2   1.916667      3.574843
# 2014-09-30     2014-09-30       3.2   1.950000      3.582994
# 2014-10-31     2014-12-31       2.7   2.008333      2.774514
# 2014-11-30     2014-12-31       2.7   2.066667      3.044588
# 2014-12-31     2014-12-31       2.7   2.125000      2.720487
# 2015-01-31     2015-03-31       3.8   2.229167      3.332187
# 2015-02-28     2015-03-31       3.8   2.333333      2.496781
# 2015-03-31     2015-03-31       3.8   2.437500      2.496781
# 2015-04-30     2015-06-30       3.3   2.533333     -0.609024
# 2015-05-31     2015-06-30       3.3   2.629167      3.921645
# 2015-06-30     2015-06-30       3.3   2.725000      3.523217
# 2015-07-31     2015-09-30       2.4   2.754167      2.875566
# 2015-08-31     2015-09-30       2.4   2.783333      2.883788
# 2015-09-30     2015-09-30       2.4   2.812500      2.869886
# ...                   ...       ...        ...           ...
# 2015-11-30     2015-12-31       2.0   2.754167      3.184124
# 2015-12-31     2015-12-31       2.0   2.725000      2.955952
# 2016-01-31     2016-03-31       1.4   2.712500      1.646613
# 2016-02-29     2016-03-31       1.4   2.700000      0.521586
# 2016-03-31     2016-03-31       1.4   2.687500      0.749582
# 2016-04-30     2016-06-30       1.2   2.625000      0.537789
# 2016-05-31     2016-06-30       1.2   2.562500      0.282919
# 2016-06-30     2016-06-30       1.2   2.500000      0.261597
# 2016-07-31     2016-09-30       1.5   2.429167      1.518337
# 2016-08-31     2016-09-30       1.5   2.358333      0.644922
# 2016-09-30     2016-09-30       1.5   2.287500      0.846620
# 2016-10-31     2016-12-31       1.8   2.250000      1.724879
# 2016-11-30     2016-12-31       1.8   2.212500      1.082904
# 2016-12-31     2016-12-31       1.8   2.175000      0.793729
# 2017-01-31     2017-03-31       2.0   2.100000      2.186019
# 2017-02-28     2017-03-31       2.0   2.025000      2.332993
# 2017-03-31     2017-03-31       2.0   1.950000      2.341491
# 2017-04-30     2017-06-30       2.2   1.904167      2.654149
# 2017-05-31     2017-06-30       2.2   1.858333      2.923088
# 2017-06-30     2017-06-30       2.2   1.812500      3.006886
# 2017-07-31     2017-09-30       2.3   1.808333      2.490449
# 2017-08-31     2017-09-30       2.3   1.804167      2.173896
# 2017-09-30     2017-09-30       2.3   1.800000      2.416694
# 2017-10-31     2017-12-31       2.6   1.825000      1.729328
# 2017-11-30     2017-12-31       2.6   1.850000      1.804681
# 2017-12-31     2017-12-31       2.6   1.875000      2.698620
# 2018-01-31     2018-03-31       2.8   1.933333      0.000000
# 2018-02-28     2018-03-31       2.8   1.991667      0.000000
# 2018-03-31     2018-03-31       2.8   2.050000      0.000000
# 2018-04-30              0       0.0   0.000000      0.000000
#
# [61 rows x 4 columns]

# %%
# Measure forecast accuracy
temp3=df_result3[df_result3['forecast_gdp']!=0]
relative_mse3=((temp3['GDP_CYOY']-temp3['forecast_gdp'])**2).mean()/((temp3['GDP_CYOY']-temp3['benchmark'])**2).mean()
relative_mse3
# Out:
# 1.1285774658641232

# %% [markdown]
# ## (4) Use autoregressive MIDAS with two indicators on a recursive basis

# %%
# n=3, ylag=1, method='recursive'
df_fc4, rmse4=forecast_all(gdp.GDP_CYOY, ip.IP_YOY, lei.LEI_YOY, start_date, end_date, 
                           x1lag='3m',x2lag='3m', ylag=1, n=3, forecast_horizon=1, 
                           poly1='expalmon', poly2='expalmon', method='recursive')

# %%
rmse4
# Out:
# [0.7857319504590432, 0.76552397705382957, 0.72485845434634388]

# %%
# Store forecast results in df_result
df_result4=store_gdp(df_fc4[0],df_fc4[1],df_fc4[2],df_result)

# %%
# Forecast results
df_result4.iloc[df_result4.index.get_loc(end_date)+1:]
# Out:
#            final_gdp_date  GDP_CYOY  benchmark  forecast_gdp
# DATE
# 2013-04-30     2013-06-30       1.0   1.833333      1.528353
# 2013-05-31     2013-06-30       1.0   1.804167      1.589848
# 2013-06-30     2013-06-30       1.0   1.775000      1.397939
# 2013-07-31     2013-09-30       1.7   1.795833      0.811102
# 2013-08-31     2013-09-30       1.7   1.816667      0.850717
# 2013-09-30     2013-09-30       1.7   1.837500      0.945653
# 2013-10-31     2013-12-31       2.7   1.879167      1.542618
# 2013-11-30     2013-12-31       2.7   1.920833      1.437942
# 2013-12-31     2013-12-31       2.7   1.962500      1.528776
# 2014-01-31     2014-03-31       1.7   1.916667      1.211766
# 2014-02-28     2014-03-31       1.7   1.870833      1.172501
# 2017-03-31     2017-03-31       2.0   1.950000      2.211316
# 2017-04-30     2017-06-30       2.2   1.904167      2.715291
# 2017-05-31     2017-06-30       2.2   1.858333      2.894647
# 2017-06-30     2017-06-30       2.2   1.812500      2.772453
# 2017-07-31     2017-09-30       2.3   1.808333      2.755385
# 2017-08-31     2017-09-30       2.3   1.804167      2.694677
# 2017-09-30     2017-09-30       2.3   1.800000      2.490234
# 2017-10-31     2017-12-31       2.6   1.825000      2.510615
# 2017-11-30     2017-12-31       2.6   1.850000      2.892509
# 2017-12-31     2017-12-31       2.6   1.875000      2.803305
# 2018-01-31     2018-03-31       2.8   1.933333      0.000000
# 2018-02-28     2018-03-31       2.8   1.991667      0.000000
# 2018-03-31     2018-03-31       2.8   2.050000      0.000000
# 2018-04-30              0       0.0   0.000000      0.000000
#
# [61 rows x 4 columns]

# %%
temp5=df_result5[df_result5['forecast_gdp']!=0]
relative_mse5=((temp5['GDP_CYOY']-temp5['forecast_gdp'])**2).mean()/((temp5['GDP_CYOY']-temp5['benchmark'])**2).mean()
relative_mse5
# Out:
# 0.751920325748791

# %% [markdown]
# ## (6) Use autoregressive MIDAS with two indicators on a recursive basis (beta weights)

# %%
# n=3, ylag=1, method='recursive', beta
df_fc6, rmse6=forecast_all(gdp.GDP_CYOY, ip.IP_YOY, lei.LEI_YOY, start_date, end_date, 
                           x1lag='3m',x2lag='3m', ylag=1, n=3, forecast_horizon=1, 
                           poly1='beta', poly2='beta', method='recursive')

# %%
# Store forecast results in df_result
df_result6=store_gdp(df_fc6[0],df_fc6[1],df_fc6[2],df_result)

# %%
# Forecast results
df_result6.iloc[df_result6.index.get_loc(end_date)+1:]
# Out:
#            final_gdp_date  GDP_CYOY  benchmark  forecast_gdp
# DATE
# 2013-04-30     2013-06-30       1.0   1.833333      1.577021
# 2013-05-31     2013-06-30       1.0   1.804167      1.397939
# 2013-06-30     2013-06-30       1.0   1.775000      1.049479
# 2013-07-31     2013-09-30       1.7   1.795833      0.772300
# 2013-08-31     2013-09-30       1.7   1.816667      0.945653
# 2013-09-30     2013-09-30       1.7   1.837500      1.324395
# 2013-10-31     2013-12-31       2.7   1.879167      1.542618
# 2013-11-30     2013-12-31       2.7   1.920833      1.451295
# 2013-12-31     2013-12-31       2.7   1.962500      1.575907
# 2014-01-31     2014-03-31       1.7   1.916667      1.211766
# 2014-02-28     2014-03-31       1.7   1.870833      1.721394
# 2014-03-31     2014-03-31       1.7   1.825000      2.342694
# 2014-04-30     2014-06-30       2.7   1.833333      1.849037
# 2014-05-31     2014-06-30       2.7   1.841667      2.131493
# 2014-06-30     2014-06-30       2.7   1.850000      2.341260
# 2014-07-31     2014-09-30       3.2   1.883333      2.460948
# 2014-08-31     2014-09-30       3.2   1.916667      2.637151
# 2014-09-30     2014-09-30       3.2   1.950000      2.612768
# 2014-10-31     2014-12-31       2.7   2.008333      2.424628
# 2014-11-30     2014-12-31       2.7   2.066667      2.859147
# 2014-12-31     2014-12-31       2.7   2.125000      3.214036
# 2015-01-31     2015-03-31       3.8   2.229167      2.394962
# 2015-02-28     2015-03-31       3.8   2.333333      2.090916
# 2015-03-31     2015-03-31       3.8   2.437500      1.550908
# 2015-04-30     2015-06-30       3.3   2.533333      1.549205
# 2015-05-31     2015-06-30       3.3   2.629167      1.704421
# 2015-06-30     2015-06-30       3.3   2.725000      3.759808
# 2015-07-31     2015-09-30       2.4   2.754167      2.272581
# 2015-08-31     2015-09-30       2.4   2.783333      2.145861
# 2015-09-30     2015-09-30       2.4   2.812500      2.954660
# ...                   ...       ...        ...           ...
# 2015-11-30     2015-12-31       2.0   2.754167      1.471917
# 2015-12-31     2015-12-31       2.0   2.725000      2.080412
# 2016-01-31     2016-03-31       1.4   2.712500      1.356387
# 2016-02-29     2016-03-31       1.4   2.700000      1.224358
# 2016-03-31     2016-03-31       1.4   2.687500      1.389161
# 2016-04-30     2016-06-30       1.2   2.625000      0.948771
# 2016-05-31     2016-06-30       1.2   2.562500      0.786941
# 2016-06-30     2016-06-30       1.2   2.500000      0.911470
# 2016-07-31     2016-09-30       1.5   2.429167      0.941951
# 2016-08-31     2016-09-30       1.5   2.358333      0.930623
# 2016-09-30     2016-09-30       1.5   2.287500      0.980863
# 2016-10-31     2016-12-31       1.8   2.250000      1.305394
# 2016-11-30     2016-12-31       1.8   2.212500      1.237342
# 2016-12-31     2016-12-31       1.8   2.175000      1.274354
# 2017-01-31     2017-03-31       2.0   2.100000      1.706732
# 2017-02-28     2017-03-31       2.0   2.025000      1.758557
# 2017-03-31     2017-03-31       2.0   1.950000      1.815662
# 2017-04-30     2017-06-30       2.2   1.904167      2.060723
# 2017-05-31     2017-06-30       2.2   1.858333      2.122497
# 2017-06-30     2017-06-30       2.2   1.812500      2.134908
# 2017-07-31     2017-09-30       2.3   1.808333      2.196599
# 2017-08-31     2017-09-30       2.3   1.804167      2.264651
# 2017-09-30     2017-09-30       2.3   1.800000      2.265001
# 2017-10-31     2017-12-31       2.6   1.825000      2.469138
# 2017-11-30     2017-12-31       2.6   1.850000      2.548597
# 2017-12-31     2017-12-31       2.6   1.875000      2.604525
# 2018-01-31     2018-03-31       2.8   1.933333      0.000000
# 2018-02-28     2018-03-31       2.8   1.991667      0.000000
# 2018-03-31     2018-03-31       2.8   2.050000      0.000000
# 2018-04-30              0       0.0   0.000000      0.000000
#
# [61 rows x 4 columns]

# %%
# Measure forecast accuracy
temp6=df_result6[df_result6['forecast_gdp']!=0]
relative_mse6=((temp6['GDP_CYOY']-temp6['forecast_gdp'])**2).mean()/((temp6['GDP_CYOY']-temp6['benchmark'])**2).mean()
relative_mse6
# Out:
# 0.7458308117239724

# %% [markdown]
# # Conclusion

# %% [markdown]
# Compared the relative MSE of MIDAS and autoregressive MIDAS on a rolling basis and recursive basis:
#
# 1. relative MSE of MIDAS on a rolling basis: 0.7431
# 2. relative MSE of MIDAS on a recursive basis: 1.2250
# 3. relative MSE of autoregressive MIDAS on a rolling basis: 1.1286
# 4. relative MSE of autoregressive MIDAS on a recursive basis: 0.8547
# 5. relative MSE of MIDAS on a rolling basis (beta weights): 0.7519
# 6. relative MSE of autoregressive MIDAS on a recursive basis (beta weights): 0.7458
#
# We find that the MIDAS on a rolling basis performs the best.
